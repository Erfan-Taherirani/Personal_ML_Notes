# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
X, _ = make_blobs(
    n_samples=1000,
    n_features=2,
    centers=4,
    cluster_std=1,
    random_state=42
)
ax = sns.scatterplot(
    x=X[:, 0],
    y=X[:, 1]
)

# %%
for k in range(2, 12):
	kmeans = KMeans(n_clusters=k, random_state=42)
	labels = kmeans.fit_predict(X)
	s_score = silhouette_score(X, labels)
	print(f"Number of Clusters: {k}, Silhouette Score: {s_score}")
# Out:
# Number of Clusters: 2, Silhouette Score: 0.5895787972208197
# Number of Clusters: 3, Silhouette Score: 0.7521964163365819
# Number of Clusters: 4, Silhouette Score: 0.7915983870089952
# Number of Clusters: 5, Silhouette Score: 0.6799227103294534
# Number of Clusters: 6, Silhouette Score: 0.5746150221168222
# Number of Clusters: 7, Silhouette Score: 0.5793370458395752
# Number of Clusters: 8, Silhouette Score: 0.41637231261626007
# Number of Clusters: 9, Silhouette Score: 0.32936331373610966
# Number of Clusters: 10, Silhouette Score: 0.3355539566271709
# Number of Clusters: 11, Silhouette Score: 0.33462805518152294

# %%
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans.fit(X)
sns.scatterplot(
    x=X[:, 0],
    y=X[:, 1],
    hue=kmeans.predict(X),
    palette="viridis"
)
# Out:
# <Axes: >
